# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mapdata = np.loadtxt("../assets/mapdata_copyright_openstreetmap_contributors.txt")
traps = pd.read_csv('../assets/train.csv')[['Date', 'Trap','Longitude', 'Latitude', 'WnvPresent']]
sprays = pd.read_csv('../assets/spray.csv')

# %%
plt.hist(mapdata)
# Out:
# (array([[   0.,    0.,    0., ...,  499.,  351.,  548.],
#         [   0.,    0.,    0., ...,  448.,  464.,  464.],
#         [   0.,    0.,    0., ...,  457.,  449.,  505.],
#         ...,
#         [   0.,    0.,    0., ..., 1531.,  138.,   46.],
#         [   0.,    0.,    0., ..., 1562.,  119.,   35.],
#         [   0.,    0.,    0., ..., 1486.,   55.,  151.]]),
#  array([0.13333333, 0.22      , 0.30666667, 0.39333333, 0.48      ,
#         0.56666667, 0.65333333, 0.74      , 0.82666667, 0.91333333,
#         1.        ]),
#  <a list of 1311 BarContainer objects>)

# %%
aspect
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f56917048849> in <module>
# ----> 1 aspect
#
# NameError: name 'aspect' is not defined

# %%
aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88, -87.5, 41.6, 42.1)

plt.figure(figsize=(20,28))
plt.imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations = traps[['Longitude', 'Latitude']].drop_duplicates().values
plt.scatter(locations[:,0], locations[:,1], marker='x', color='red', s=100)
plt.scatter(traps['Longitude'], traps['Latitude'], marker='o', color='blue')
plt.scatter([-87.933, -87.752], [41.995, 41.786], marker='*', color = 'black', s=500)
plt.savefig('heatmap.png')
